# %%
import pandas as pd

# %% [markdown]
# ### Par datiem
#
# Vidējās darījumu cenas dzīvokļiem
# Dati apkopoti par darījumiem ar dzīvojamām telpu grupām, kas Kadastra informācijas sistēmā reģistrētas dzīvokļu īpašumu sastāvā.
#
# Vidējās dzīvokļu darījumu cenas tiek attēlotas EUR/m2 un aprēķinātas kā statistiskais rādītājs mediāna (vidējā vērtība sakārtotā skaitļu kopā).
#
# Ņemot vērā nekustamo īpašumu tirgū cenu atšķirības pēc 2000. gada būvētām daudzdzīvokļu mājām, atsevišķi nodalīti dzīvokļu darījumi:
#
# Ēkās, kas būvētas pirms 2000. gada;
# Ēkās, kas būvētas pēc 2000. gada jeb jauno projektu mājas.
# Vidējās darījumu cenas atspoguļotas pa dažādām teritoriju grupām:
#
# Dzīvokļiem ēkās, kas būvētas pirms 2000.gada – Rīgā, Jūrmalā, pārējās valstspilsētās, Rīgas ietekmes teritorijās, pilsētās ar augstāku vērtību līmeni un pilsētās ar zemāku vērtību līmeni kopā ar lauku teritorijām;
# Jauno projektu dzīvokļiem – Rīgā, Jūrmalā un Rīgas ietekmes teritorijās.
# Visos grafikos ar vertikālām līnijām parādīts spēkā esošai kadastrālo vērtību bāzei izmantotās nekustamā īpašuma tirgus informācijas atskaites punkts – 2013. gads un jaunai bāzei izmantotās tirgus informācijas atskaites punkts – 2019. gada 1. jūlijs.
#
# 2018.gadā pirmreizēji publicēto darījumu statistika var atšķirties no pašreiz sagatavotās, jo tirgus datu bāze papildināta ar iepriekšējo gadu darījumiem, kas zemesgrāmatā reģistrēti vēlāk, kā arī precizēti datu kopu sagatavošanas nosacījumi teritoriju, objektu, darījumu cenu atlasei.
#
# Atbilstoši administratīvi teritoriālai reformai, mainīts teritoriju dalījums un tas ietekmē arī aprēķinu rezultātus. Skaidrojums par teritoriju kopu izmaiņām pieejams šeit:
#
# Dati pieejami no 2011. gada

# %%
# Sērijveida dzīvokļu cenas Rīgā un Jūrmalā
url_dz_cenas_riga_jurmala_serij_2021 = 'https://data.gov.lv/dati/dataset/0c77683b-74a0-47a2-834b-b349cedb8beb/resource/bbe18a38-db35-4e47-9bdc-7f9cf651507b/download/dz_cenas_riga_jurmala_serij_2021-1.csv'
dz_cenas_riga_jurmala_serij_2021 = pd.read_csv(url_dz_cenas_riga_jurmala_serij_2021)

# Dzīvokļu cenas Rīgas un Jūrmalas jaunajos 
url_dz_cenas_riga_jurmala_jaunie_2021 = 'https://data.gov.lv/dati/dataset/0c77683b-74a0-47a2-834b-b349cedb8beb/resource/3f4e4c80-1296-459b-b96f-9d3b81b3b26b/download/dz_cenas_riga_jurmala_jaunie_2021-1.csv'
dz_cenas_riga_jurmala_jaunie_2021 = pd.read_csv(url_dz_cenas_riga_jurmala_jaunie_2021)

# Dzīvokļu cenas Rīgas ietekmes teritorijā
url_dz_cenas_rigas_ietek_terit_2021 = 'https://data.gov.lv/dati/dataset/0c77683b-74a0-47a2-834b-b349cedb8beb/resource/f2c7f33e-8248-48bf-8cb3-56f9ea7eacf5/download/dz_cenas_rigas_ietek_terit_2021-1.csv'
dz_cenas_rigas_ietek_terit_2021 = pd.read_csv(url_dz_cenas_rigas_ietek_terit_2021)


# Sērijveida dzīvoklu cenas valstspilsētās
url_dz_cenas_valstspilsetas_serij_2021 = 'https://data.gov.lv/dati/dataset/0c77683b-74a0-47a2-834b-b349cedb8beb/resource/0547641e-ac38-4c7e-8fcd-bc095ff7a4c0/download/dz_cenas_valstspilsetas_serij_2021-1.csv'
dz_cenas_valstspilsetas_serij_2021 = pd.read_csv(url_dz_cenas_valstspilsetas_serij_2021)

# Dzīvokļu cenas pilsētās ar augstāku vērtību 
url_dz_cenas_reg_augsts_vert_lim_2021 = 'https://data.gov.lv/dati/dataset/0c77683b-74a0-47a2-834b-b349cedb8beb/resource/767fa84b-f89c-4e0a-90b0-702abbb2a7ba/download/dz_cenas_reg_augsts_vert_lim_2021-1.csv'
dz_cenas_reg_augsts_vert_lim_2021 = pd.read_csv(url_dz_cenas_reg_augsts_vert_lim_2021)

# Dzīvokļu cenas pilsētās ar zemāku vērtību līmeni
url_dz_cenas_reg_zems_vert_lim_2021 = 'https://data.gov.lv/dati/dataset/0c77683b-74a0-47a2-834b-b349cedb8beb/resource/987ec4a7-7e99-45c7-abf7-4fe6d2d1e1fb/download/dz_cenas_reg_zems_vert_lim_2021-1.csv'
dz_cenas_reg_zems_vert_lim_2021 = pd.read_csv(url_dz_cenas_reg_zems_vert_lim_2021)

dz_cenas_riga_jurmala_serij_2021.head()
# Out:
#   Gads un pusgads  Vidējā cena (EUR/m2) Rīga_Centrs  \
# 0          2011-1                              1019
# 1          2011-2                               885
# 2          2012-1                               888
# 3          2012-2                              1063
# 4          2013-1                               957
#
#    Darījumu skaits Rīga_Centrs  Vidējā cena (EUR/m2) Rīga_Mikrorajoni  \
# 0                           97                                    449
# 1                          138                                    446
# 2                          150                                    469
# 3                          212                                    498
# 4                          177                                    541
#
#    Darījumu skaits Rīga_Mikrorajoni  \
# 0                              1165
# 1                              1491
# 2                              1415
# 3                              1679
# 4                              1748
#
# ...

# %%
dz_cenas_reg_zems_vert_lim_2021.head()
# Out:
#   Gads un pusgads  Vidējā cena (EUR/m2) Kurzeme  Darījumu skaits Kurzeme  \
# 0          2011-1                            87                       60
# 1          2011-2                            76                       92
# 2          2012-1                            64                       63
# 3          2012-2                            68                       94
# 4          2013-1                            74                       97
#
#    Vidējā cena (EUR/m2) Latgale  Darījumu skaits Latgale  \
# 0                            67                       56
# 1                            46                       92
# 2                            52                      103
# 3                            39                      113
# 4                            44                       84
#
#    Vidējā cena (EUR/m2) Vidzeme  Darījumu skaits Vidzeme  \
# 0                            73                       72
# 1                            90                      111
# ...
